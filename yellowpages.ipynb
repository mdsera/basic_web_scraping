# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.yellowpages.com/search?search_terms=Restaurants&geo_location_terms=Los%20Angeles%2C%20CA"
url_1 = url + "&page=" + str(2)
soup = BeautifulSoup(requests.get(url_1).content)
print(soup.prettify()) #better view of the HTML code
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="utf-8" name="charset"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <title>
#    Best 30 Restaurants in Los Angeles, CA with Reviews - Page 2 - YP.com
#   </title>
#   <meta content="Popular &amp; reviewed Restaurants in Los Angeles, CA. Find reviews, menus, or even order online - THE REAL YELLOW PAGES®" name="description"/>
#   <meta content="noindex, follow" name="robots"/>
#   <meta content="app-id=284806204, app-argument=ypmobile://srp?search_category=restaurants&amp;latitude=34.0522342&amp;longitude=-118.2436849" name="apple-itunes-app"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Best 30 Restaurants in Los Angeles, CA with Reviews - Page 2 - YP.com" property="og:title"/>
# ...

# %%
for link in soup.find_all("a"):
#     if "http" in link.get("href"):
    print(link.text,link.get("href"))
# Out:
#  /
# Use My Location #
#  #
# Log In /login
# Sign Up /register
# Auto Body Shops https://www.yellowpages.com/los-angeles-ca/auto-body-shops
# Auto Glass Repair https://www.yellowpages.com/los-angeles-ca/auto-glass-repair
# Auto Parts https://www.yellowpages.com/los-angeles-ca/auto-parts
# Auto Repair https://www.yellowpages.com/los-angeles-ca/auto-repair
# Car Detailing https://www.yellowpages.com/los-angeles-ca/car-detailing
# Oil Change https://www.yellowpages.com/los-angeles-ca/oil-change
# Roadside Assistance https://www.yellowpages.com/los-angeles-ca/roadside-assistance
# Tire Shops https://www.yellowpages.com/los-angeles-ca/tire-shops
# Towing https://www.yellowpages.com/los-angeles-ca/towing
# Window Tinting https://www.yellowpages.com/los-angeles-ca/window-tinting
# Barber Shops https://www.yellowpages.com/los-angeles-ca/barber-shops
# Beauty Salons https://www.yellowpages.com/los-angeles-ca/beauty-salons
# ...

# %%
g_data = soup.find_all("div",{"class":"info"})
for item in g_data:
    print(item.contents[0].find_all("a", {"class": "business-name"})[0].text)
    try:    
        print(item.contents[1].find_all("div", {"class": "street-address"})[0].text, 
              item.contents[1].find_all("div", {"class": "locality"})[0].text, '\n')
    except:
        pass
# Out:
# Don Chuy's Restaurant
# 11707 W Washington Blvd Los Angeles, CA 90066
#
# Corner Bakery Cafe
# 1019 Westwood Blvd Los Angeles, CA 90024
#
# Vinoteque
# 7469 Melrose Ave Los Angeles, CA 90046
#
# The Good Pizza
# 7929 Emerson Ave Los Angeles, CA 90045
#
# Berri's Pizza Cafe
# 8412 W 3rd St Los Angeles, CA 90048
#
# Fish Grill
# 9618 W Pico Blvd Los Angeles, CA 90035
#
# Harand USA
# 11769 Santa Monica Blvd Los Angeles, CA 90025
#
# The Stand "American Classics Redefined"
# 2000 Avenue Of The Stars Los Angeles, CA 90067
#
# Santino's Restaurant
# 1253 Vine St Los Angeles, CA 90038
#
# Renaissance Restaurant
# 5930 Franklin Ave Los Angeles, CA 90028
#
# Sweet Tomatoes
# 8516 W 3rd St Los Angeles, CA 90048
#
# Headlines Diner & Press Club
# 10922 Kinross Ave Los Angeles, CA 90024
#
# A Votre Sante
# 13016 San Vicente Blvd Los Angeles, CA 90049
#
# Upstairs 2
# 2311 Cotner Ave Los Angeles, CA 90064
#
# Sansui Restaurant
# 2040 Hillhurst Ave Los Angeles, CA 90027
#
# El Asador Restaurant
# ...

# %%
def get_data(url, n_pages):
    data_dic = {}
    for page in range(n_pages):
        if n_pages < 2:
            url1 = url
            soup = BeautifulSoup(requests.get(url_1).content)
            g_data = soup.find_all("div",{"class":"info"})
            for item in g_data:
                try:
                    data_dic.update({item.contents[0].find_all("a", {"class": "business-name"})[0].text : 
                                    item.contents[1].find_all("div", {"class": "street-address"})[0].text + 
                                    item.contents[1].find_all("div", {"class": "locality"})[0].text})
                except:
                    pass
        else:
            url_1 = url + "&page=" + str(page)
            soup = BeautifulSoup(requests.get(url_1).content)
            g_data = soup.find_all("div",{"class":"info"})
            for item in g_data:
                try:
                    data_dic.update({item.contents[0].find_all("a", {"class": "business-name"})[0].text : 
                                    item.contents[1].find_all("div", {"class": "street-address"})[0].text + 
                                    item.contents[1].find_all("div", {"class": "locality"})[0].text})
                except:
                    pass
    return data_dic

# %%
new_data = get_data(url,2)

# %%
new_data
# Out:
# {'Palermo Italian Restaurant': '1858 N Vermont AveLos Angeles, CA 90027',
#  'Casa Bianca Pizza Pie': '1650 Colorado BlvdLos Angeles, CA 90041',
#  'Dulan Soul Food Kitchen': '1714 W Century BlvdLos Angeles, CA 90047',
#  'Marouch Restaurant': '4905 Santa Monica BlvdLos Angeles, CA 90029',
#  "Rocco's Italian Kitchen": '6335 Wilshire BlvdLos Angeles, CA 90048',
#  'Carlitos Gardel Restaurant': '7963 Melrose AveLos Angeles, CA 90046',
#  'Angelini Osteria': '7313 Beverly BlvdLos Angeles, CA 90036',
#  'Vincenti Restaurant': '11930 San Vicente BlvdLos Angeles, CA 90049',
#  'Fish Grill': '7226 Beverly BlvdLos Angeles, CA 90036',
#  "Mauro's Restaurant": '8112 Melrose AveLos Angeles, CA 90046',
#  "Dinah's Family Restaurant": '6521 S Sepulveda BlvdLos Angeles, CA 90045',
#  'Canele': '3219 Glendale BlvdLos Angeles, CA 90039',
#  "Maria's Italian Kitchen": '10761 W Pico BlvdLos Angeles, CA 90064',
#  'TGI Fridays': '6721 La Tijera BlvdLos Angeles, CA 90045',
# ...
